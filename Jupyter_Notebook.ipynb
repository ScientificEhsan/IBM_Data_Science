# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
# Final Project: Introduction to Data Science Notebook

# %% [markdown]
# ## Introduction
#
# This notebook demonstrates basic use of Markdown and Python code cells in a Jupyter environment. We will cover markup for lists, tables, and simple arithmetic operations, and show how to convert units. Finally, we will share the completed notebook on GitHub.

# %% [markdown]
# ## Data Science Languages
#
# - Python
# - R
# - Julia

# %% [markdown]
# ## Data Science Libraries
#
# - NumPy
# - pandas
# - Matplotlib
# - scikit‑learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
#
# | Tool         | Purpose                   |
# |--------------|---------------------------|
# | Jupyter      | Interactive notebooks     |
# | Git / GitHub | Version control & sharing |
# | VS Code       | Code editor               |
# | Docker       | Containerization          |

# %% [markdown]
# ## Examples of Arithmetic Expressions
#
# Below are some simple examples of multiplication and addition in Python.

# %%
# Multiply 7 by 6 and then add 3
result = 7 * 6 + 3
print("7 × 6 + 3 =", result)

# %%
# Convert minutes to hours
minutes = 135
hours = minutes / 60
print(f"{minutes} minutes is {hours:.2f} hours")

# %% [markdown]
# ## Objectives
#
# 1. Practice Markdown formatting
# 2. Demonstrate simple Python arithmetic
# 3. Convert units programmatically
# 4. Publish and share work via GitHub

# %% [markdown]
# **Author:** Shafqat Ehsan

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
